# %%
from mlbox.preprocessing import *
from mlbox.optimisation import *
from mlbox.prediction import *
import warnings
warnings.filterwarnings("ignore")

# %%
target_name = 'SalePrice'

# %%
paths = ["train.csv","test.csv"]
rd = Reader(sep=',')
df = rd.train_test_split(paths, target_name)
# Out:
# reading csv : train.csv ...
# cleaning data ...
# CPU time: 2.1471176147460938 seconds
#
# reading csv : test.csv ...
# cleaning data ...
# CPU time: 0.18936872482299805 seconds
#
# > Number of common features : 80
#
# gathering and crunching for train and test datasets ...
# reindexing for train and test datasets ...
# dropping training duplicates ...
# dropping constant variables on training set ...
#
# > Number of categorical features: 43
# > Number of numerical features: 37
# > Number of training samples : 1460
# > Number of test samples : 1459
#
# > Top sparse features (% missing values on train set):
# PoolQC         99.5
# MiscFeature    96.3
# Alley          93.8
# Fence          80.8
# FireplaceQu    47.3
# dtype: float64
#
# > Task : regression
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
dft = Drift_thresholder()
df = dft.fit_transform(df)
# Out:
# computing drifts ...
# CPU time: 0.5379059314727783 seconds
#
# > Top 10 drifts
#
# ('Id', 1.0)
# ('Exterior2nd', 0.06692247765095138)
# ('TotRmsAbvGrd', 0.06244630217813274)
# ('Fireplaces', 0.04357188363693654)
# ('1stFlrSF', 0.03847960830314534)
# ('Condition1', 0.03844534950079037)
# ('BldgType', 0.03602915537598572)
# ('YrSold', 0.03556155580112552)
# ('MSZoning', 0.03215772151292695)
# ('Exterior1st', 0.03189699655661604)
#
# > Deleted variables : ['Id']
# > Drift coefficients dumped into directory : save

# %%
df['train'].to_csv('preprocessed_train.csv', index=False)

# %%
df['test'].to_csv('preprocessed_test.csv', index=False)

# %%
rmse = make_scorer(lambda y_true, y_pred: np.sqrt(np.sum((y_true - y_pred)**2)/len(y_true)), 
                   greater_is_better=False, 
                   needs_proba=False)

opt = Optimiser(scoring = rmse, n_folds = 5)

# %% [markdown]
# # LightGBM

# %%
space = {
    'est__strategy':{"search":"choice",
                    "space":["LightGBM"]},
    'est__n_estimators':{"search":"choice",
                    "space":[150, 300]},
    'est__colsample_bytree':{"search":"uniform",
                    "space":[0.8, 0.95]},
    'est__subsample':{"search":"uniform",
                    "space":[0.8, 0.95]},
    'est__max_depth':{'search':"choice",
                    "space":[5,6,7,8,9]},
    'est__learning_rate':{"search":"choice",
                    "space":[0.01, 0.07]},
    'est__n_jobs':{'search':'choice',
                  'space':[4]}
}

params = opt.optimise(space, df, 50)
# Out:
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.9390547369633679, 'learning_rate': 0.07, 'max_depth': 8, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.831433746026626, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28200.42790032871
# VARIANCE : 4459.585096200776 (fold 1 = -28119.99417067384, fold 2 = -29736.876106566782, fold 3 = -26574.073079035785, fold 4 = -35156.2900158106, fold 5 = -21414.906129556537)
# CPU time: 0.8072447776794434 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8017804870254053, 'learning_rate': 0.07, 'max_depth': 5, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8103485742586571, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28202.54010845216
# VARIANCE : 4524.19945488081 (fold 1 = -28951.616763991737, fold 2 = -28704.022266068725, fold 3 = -26557.3878707229, fold 4 = -35426.39093626268, fold 5 = -21373.282705214773)
# CPU time: 0.6554746627807617 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.9125614587304994, 'learning_rate': 0.07, 'max_depth': 8, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.847346438992349, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28195.651917724033
# VARIANCE : 4580.200117965464 (fold 1 = -28364.224898099957, fold 2 = -29991.34684356189, fold 3 = -26844.104649101602, fold 4 = -34947.0474454236, fold 5 = -20831.53575243311)
# CPU time: 0.7994122505187988 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8214342750803253, 'learning_rate': 0.07, 'max_depth': 7, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.879888050760885, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28297.018519728277
# VARIANCE : 4396.7314826853435 (fold 1 = -28742.809483165154, fold 2 = -29612.027873784624, fold 3 = -26876.49026731139, fold 4 = -34933.220210767824, fold 5 = -21320.544763612375)
# CPU time: 0.7468836307525635 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8014360275818103, 'learning_rate': 0.07, 'max_depth': 8, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8117741550964782, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -27983.40921535051
# VARIANCE : 4669.735558693612 (fold 1 = -28752.79760632377, fold 2 = -28814.725479434757, fold 3 = -25913.608326657588, fold 4 = -35406.66390416374, fold 5 = -21029.250760172723)
# CPU time: 0.7857687473297119 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8242099796127016, 'learning_rate': 0.07, 'max_depth': 6, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.9059895174748583, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28455.449565381732
# VARIANCE : 4480.589189413786 (fold 1 = -28822.636790802353, fold 2 = -30428.19924849603, fold 3 = -26327.029240633445, fold 4 = -35124.61883543728, fold 5 = -21574.76371153955)
# CPU time: 0.7054462432861328 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8332401430213776, 'learning_rate': 0.07, 'max_depth': 9, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8512720381271267, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28164.307264685114
# VARIANCE : 4554.0053262228585 (fold 1 = -28336.409824628074, fold 2 = -29666.216103295254, fold 3 = -26339.29857176567, fold 4 = -35242.21322239415, fold 5 = -21237.398601342426)
# CPU time: 0.8130676746368408 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.9083838763838044, 'learning_rate': 0.07, 'max_depth': 6, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.9395238984832024, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28370.681562530564
# VARIANCE : 4579.9544909306305 (fold 1 = -28398.09324455078, fold 2 = -30133.58615695596, fold 3 = -27038.311520202773, fold 4 = -35208.93082697546, fold 5 = -21074.486063967826)
# CPU time: 0.7180564403533936 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8352132968883118, 'learning_rate': 0.07, 'max_depth': 8, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.859396750119391, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28283.75713806778
# VARIANCE : 4402.873038547517 (fold 1 = -28931.159631585102, fold 2 = -29571.351124552777, fold 3 = -26168.524828514823, fold 4 = -35095.44393609851, fold 5 = -21652.306169587686)
# CPU time: 0.784221887588501 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8658127242616465, 'learning_rate': 0.07, 'max_depth': 7, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.9317374162273944, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28344.462506286236
# VARIANCE : 4295.597123345799 (fold 1 = -28679.33077362222, fold 2 = -29820.04145097445, fold 3 = -26488.723077807143, fold 4 = -34944.589467133475, fold 5 = -21789.62776189388)
# CPU time: 0.7522222995758057 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8296004601524769, 'learning_rate': 0.07, 'max_depth': 6, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8474150682106374, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28455.449565381732
# VARIANCE : 4480.589189413786 (fold 1 = -28822.636790802353, fold 2 = -30428.19924849603, fold 3 = -26327.029240633445, fold 4 = -35124.61883543728, fold 5 = -21574.76371153955)
# CPU time: 0.7083196640014648 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8396292081744304, 'learning_rate': 0.07, 'max_depth': 5, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8459072764388196, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28401.733327750837
# VARIANCE : 4619.560447195813 (fold 1 = -28399.065734552853, fold 2 = -30243.232536849537, fold 3 = -26790.32629061096, fold 4 = -35383.37422071656, fold 5 = -21192.667856024276)
# CPU time: 0.6549170017242432 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.9217848871196339, 'learning_rate': 0.07, 'max_depth': 9, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.9246308718530172, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28456.643387283628
# VARIANCE : 4374.363513675059 (fold 1 = -28934.670356903942, fold 2 = -29855.314396250415, fold 3 = -26761.041002064387, fold 4 = -35096.58684748874, fold 5 = -21635.604333710653)
# CPU time: 0.8382978439331055 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8297838780508768, 'learning_rate': 0.07, 'max_depth': 5, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8943659839945388, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28450.418604879735
# VARIANCE : 4574.6477326700515 (fold 1 = -28193.168874916115, fold 2 = -30146.207943899495, fold 3 = -26931.032539033127, fold 4 = -35540.07329465925, fold 5 = -21441.610371890667)
# CPU time: 0.6576755046844482 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8561945272459645, 'learning_rate': 0.07, 'max_depth': 5, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.815454455117095, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28236.1761221911
# VARIANCE : 4572.847984203499 (fold 1 = -28294.48203874608, fold 2 = -30207.398452851583, fold 3 = -26299.722721963204, fold 4 = -35150.65130971682, fold 5 = -21228.626087677814)
# CPU time: 0.658759355545044 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.9193592172386724, 'learning_rate': 0.07, 'max_depth': 8, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.9171644394057403, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28369.075949453545
# VARIANCE : 4565.086757560552 (fold 1 = -28710.707368848613, fold 2 = -30247.23014423064, fold 3 = -26946.94018856409, fold 4 = -34977.93671594853, fold 5 = -20962.56532967586)
# CPU time: 0.7998929023742676 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8447681272379842, 'learning_rate': 0.07, 'max_depth': 6, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8653857449124205, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28561.07890238148
# VARIANCE : 4396.751169119238 (fold 1 = -28474.499948366458, fold 2 = -30382.11045178211, fold 3 = -26771.43056543185, fold 4 = -35301.68980538963, fold 5 = -21875.66374093734)
# CPU time: 0.7124216556549072 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8551362520094774, 'learning_rate': 0.07, 'max_depth': 9, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8748337236912023, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28438.29409966909
# VARIANCE : 4331.463211429284 (fold 1 = -28292.795416773333, fold 2 = -29999.09650909023, fold 3 = -26239.292784297522, fold 4 = -35395.5025944993, fold 5 = -22264.78319368507)
# CPU time: 0.8210854530334473 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.9132262724952396, 'learning_rate': 0.07, 'max_depth': 5, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8452809565414867, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28662.571345794684
# VARIANCE : 4702.361318081564 (fold 1 = -28516.68421935726, fold 2 = -30362.451896208455, fold 3 = -27235.043444081104, fold 4 = -35865.84738240388, fold 5 = -21332.82978692273)
# CPU time: 0.6666185855865479 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.9362819630980774, 'learning_rate': 0.07, 'max_depth': 5, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.890308048165292, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28366.573157909752
# VARIANCE : 4742.571351102297 (fold 1 = -28141.542403167976, fold 2 = -30374.992347475814, fold 3 = -26884.682365151228, fold 4 = -35500.53702455838, fold 5 = -20931.111649195333)
# CPU time: 0.6677455902099609 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8081578825057418, 'learning_rate': 0.07, 'max_depth': 9, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8252125881419161, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28055.735446561885
# VARIANCE : 4565.893868136337 (fold 1 = -28980.742229455467, fold 2 = -28696.348800563977, fold 3 = -25954.587195678327, fold 4 = -35338.2230157505, fold 5 = -21308.775991361166)
# CPU time: 0.8136835098266602 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8001505873930118, 'learning_rate': 0.07, 'max_depth': 9, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8001335821059329, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -27900.1496177202
# VARIANCE : 4374.885487017014 (fold 1 = -28730.613124280906, fold 2 = -28696.348800563977, fold 3 = -25989.093614342655, fold 4 = -34775.916558052275, fold 5 = -21308.775991361166)
# CPU time: 0.8086972236633301 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8838113651159473, 'learning_rate': 0.07, 'max_depth': 8, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8072991984272975, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28477.536238147673
# VARIANCE : 4282.335649426699 (fold 1 = -28555.51492022374, fold 2 = -29599.351647157953, fold 3 = -27105.394451230568, fold 4 = -35216.89795495228, fold 5 = -21910.52221717382)
# CPU time: 0.7915217876434326 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8103187128449671, 'learning_rate': 0.07, 'max_depth': 9, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8012680449217947, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28166.742560934148
# VARIANCE : 4609.893846929043 (fold 1 = -28980.742229455467, fold 2 = -29317.62945617058, fold 3 = -25954.587195678327, fold 4 = -35338.2230157505, fold 5 = -21242.53090761588)
# CPU time: 0.8120777606964111 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8787608431700914, 'learning_rate': 0.07, 'max_depth': 9, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8284179075057926, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28258.72540881407
# VARIANCE : 4256.490625786975 (fold 1 = -28557.456910187768, fold 2 = -29482.615898102693, fold 3 = -26673.092182411572, fold 4 = -34866.141452655276, fold 5 = -21714.320600713025)
# CPU time: 0.8279643058776855 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8000308635006212, 'learning_rate': 0.07, 'max_depth': 8, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8022953203514036, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -27983.40921535051
# VARIANCE : 4669.735558693612 (fold 1 = -28752.79760632377, fold 2 = -28814.725479434757, fold 3 = -25913.608326657588, fold 4 = -35406.66390416374, fold 5 = -21029.250760172723)
# CPU time: 0.7805886268615723 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8917345255236208, 'learning_rate': 0.07, 'max_depth': 7, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8198858632235524, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28108.338008852275
# VARIANCE : 4574.254226485673 (fold 1 = -28288.03684432987, fold 2 = -29846.208161458344, fold 3 = -26704.25015506666, fold 4 = -34903.662038863105, fold 5 = -20799.532844543388)
# CPU time: 0.7779505252838135 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8149677307126928, 'learning_rate': 0.07, 'max_depth': 9, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8361237887526285, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28166.742560934148
# VARIANCE : 4609.893846929043 (fold 1 = -28980.742229455467, fold 2 = -29317.62945617058, fold 3 = -25954.587195678327, fold 4 = -35338.2230157505, fold 5 = -21242.53090761588)
# CPU time: 0.8125457763671875 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8174584367262177, 'learning_rate': 0.07, 'max_depth': 8, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8003613102677712, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28285.19804655963
# VARIANCE : 4661.119516854788 (fold 1 = -28973.750503144507, fold 2 = -29575.930061254167, fold 3 = -25983.753184552043, fold 4 = -35557.591060990904, fold 5 = -21334.965422856545)
# CPU time: 0.7838501930236816 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.9484651522479309, 'learning_rate': 0.07, 'max_depth': 8, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.9498171043997932, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28242.54017198952
# VARIANCE : 4474.938763780568 (fold 1 = -28684.878440097793, fold 2 = -29308.58649787094, fold 3 = -26756.182820009864, fold 4 = -35180.76269634941, fold 5 = -21282.2904056196)
# CPU time: 0.8078467845916748 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8003431936552837, 'learning_rate': 0.07, 'max_depth': 7, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8349860335659287, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28310.02963242223
# VARIANCE : 4444.207421924947 (fold 1 = -28894.36030944145, fold 2 = -28717.975297432633, fold 3 = -26140.66838608614, fold 4 = -35712.09332497236, fold 5 = -22085.050844178557)
# CPU time: 0.7469115257263184 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.848028352706608, 'learning_rate': 0.07, 'max_depth': 8, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8135726744261422, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28332.238775572372
# VARIANCE : 4168.364856419152 (fold 1 = -28459.9710906014, fold 2 = -29566.879501046926, fold 3 = -26818.48243116591, fold 4 = -34851.25091828272, fold 5 = -21964.609936764908)
# CPU time: 0.7874159812927246 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8594112994905827, 'learning_rate': 0.07, 'max_depth': 9, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8056252265366807, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28420.91419637868
# VARIANCE : 4303.597399211041 (fold 1 = -28292.795416773333, fold 2 = -29999.09650909023, fold 3 = -26239.292784297522, fold 4 = -35308.603078047236, fold 5 = -22264.78319368507)
# CPU time: 0.8235747814178467 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8066169975648718, 'learning_rate': 0.07, 'max_depth': 8, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8194090648228842, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -27957.63144479831
# VARIANCE : 4540.335846834915 (fold 1 = -28973.750503144507, fold 2 = -28814.725479434757, fold 3 = -25983.753184552043, fold 4 = -34986.677296687536, fold 5 = -21029.250760172723)
# CPU time: 0.7865526676177979 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.9006779157228624, 'learning_rate': 0.07, 'max_depth': 9, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8222975894901592, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28174.56904260292
# VARIANCE : 4657.268586290628 (fold 1 = -27962.86261845607, fold 2 = -30002.331208521384, fold 3 = -26720.373117323063, fold 4 = -35267.809267196855, fold 5 = -20919.46900151723)
# CPU time: 0.8287012577056885 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8068542155527096, 'learning_rate': 0.07, 'max_depth': 7, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8378892235645616, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28234.22167391486
# VARIANCE : 4246.602123015531 (fold 1 = -28576.613892322603, fold 2 = -28717.975297432633, fold 3 = -26546.17680224852, fold 4 = -35245.291533391974, fold 5 = -22085.050844178557)
# CPU time: 0.7541019916534424 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8693759970318575, 'learning_rate': 0.07, 'max_depth': 8, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.858634425456839, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28286.928728324314
# VARIANCE : 4299.263685900033 (fold 1 = -28558.282392717432, fold 2 = -29422.068423180397, fold 3 = -26763.793467293282, fold 4 = -35005.93367473906, fold 5 = -21684.565683691413)
# CPU time: 0.7911760807037354 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8200662063469779, 'learning_rate': 0.07, 'max_depth': 6, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8711041125095904, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28270.074394088064
# VARIANCE : 4610.1239919811715 (fold 1 = -28822.636790802353, fold 2 = -30025.39811162948, fold 3 = -26327.029240633445, fold 4 = -35124.61883543728, fold 5 = -21050.688991937746)
# CPU time: 0.7041265964508057 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.824672183130456, 'learning_rate': 0.07, 'max_depth': 8, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8803929411610576, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28340.975322981994
# VARIANCE : 4533.158835439226 (fold 1 = -28659.756942169148, fold 2 = -29571.351124552777, fold 3 = -26263.871317609457, fold 4 = -35557.591060990904, fold 5 = -21652.306169587686)
# CPU time: 0.7826216220855713 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8459499985882657, 'learning_rate': 0.07, 'max_depth': 9, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8570027615519864, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28373.588689902535
# VARIANCE : 4407.631907497985 (fold 1 = -28888.548892632774, fold 2 = -29338.890533954564, fold 3 = -26412.514978554194, fold 4 = -35395.5025944993, fold 5 = -21832.486449871853)
# CPU time: 0.818495512008667 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8055528032831755, 'learning_rate': 0.07, 'max_depth': 6, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8166878873189086, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28315.131237216818
# VARIANCE : 4524.0139553368335 (fold 1 = -29061.511241254517, fold 2 = -29248.014963959693, fold 3 = -26601.35728956598, fold 4 = -35331.26266836198, fold 5 = -21333.510022941922)
# CPU time: 0.7053883075714111 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8241451713371625, 'learning_rate': 0.07, 'max_depth': 7, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.9070286767893138, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28197.9887125722
# VARIANCE : 4493.8163476040745 (fold 1 = -28742.809483165154, fold 2 = -29450.33169446882, fold 3 = -26876.49026731139, fold 4 = -34933.220210767824, fold 5 = -20987.09190714781)
# CPU time: 0.7529911994934082 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8376571323063873, 'learning_rate': 0.07, 'max_depth': 8, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8295185262960374, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28345.323566802057
# VARIANCE : 4309.326791294227 (fold 1 = -28931.159631585102, fold 2 = -29566.879501046926, fold 3 = -26168.524828514823, fold 4 = -35095.44393609851, fold 5 = -21964.609936764908)
# CPU time: 0.7921319007873535 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8144079360910859, 'learning_rate': 0.07, 'max_depth': 9, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8108647709330281, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28166.742560934148
# VARIANCE : 4609.893846929043 (fold 1 = -28980.742229455467, fold 2 = -29317.62945617058, fold 3 = -25954.587195678327, fold 4 = -35338.2230157505, fold 5 = -21242.53090761588)
# CPU time: 0.8780319690704346 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8686961212191396, 'learning_rate': 0.07, 'max_depth': 6, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8399386677869143, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28651.115430032067
# VARIANCE : 4429.851373672416 (fold 1 = -28945.86053439681, fold 2 = -30403.669602914066, fold 3 = -27122.019324669367, fold 4 = -35192.27828731552, fold 5 = -21591.749400864588)
# CPU time: 0.7097733020782471 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.9382283162302882, 'learning_rate': 0.07, 'max_depth': 5, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8522971276615484, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28366.573157909752
# VARIANCE : 4742.571351102297 (fold 1 = -28141.542403167976, fold 2 = -30374.992347475814, fold 3 = -26884.682365151228, fold 4 = -35500.53702455838, fold 5 = -20931.111649195333)
# CPU time: 0.6662230491638184 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8303705038947761, 'learning_rate': 0.07, 'max_depth': 8, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8862415572524253, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28340.975322981994
# VARIANCE : 4533.158835439226 (fold 1 = -28659.756942169148, fold 2 = -29571.351124552777, fold 3 = -26263.871317609457, fold 4 = -35557.591060990904, fold 5 = -21652.306169587686)
# CPU time: 0.781212568283081 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8902849515671241, 'learning_rate': 0.07, 'max_depth': 9, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.9010581908639588, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28229.596300358342
# VARIANCE : 4379.594017590359 (fold 1 = -27962.86261845607, fold 2 = -29482.615898102693, fold 3 = -26720.373117323063, fold 4 = -35267.809267196855, fold 5 = -21714.320600713025)
# CPU time: 0.8294649124145508 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8000403808191322, 'learning_rate': 0.07, 'max_depth': 7, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.8641123905369923, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28310.02963242223
# VARIANCE : 4444.207421924947 (fold 1 = -28894.36030944145, fold 2 = -28717.975297432633, fold 3 = -26140.66838608614, fold 4 = -35712.09332497236, fold 5 = -22085.050844178557)
# CPU time: 0.7488958835601807 seconds
# ##################################################### testing hyper-parameters... #####################################################
# >>> NA ENCODER :{'numerical_strategy': 'mean', 'categorical_strategy': '<NULL>'}
# >>> CA ENCODER :{'strategy': 'label_encoding'}
# >>> ESTIMATOR :{'strategy': 'LightGBM', 'colsample_bytree': 0.8400257231751121, 'learning_rate': 0.07, 'max_depth': 5, 'n_estimators': 150, 'n_jobs': 4, 'subsample': 0.9469672856278191, 'boosting_type': 'gbdt', 'class_weight': None, 'importance_type': 'split', 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': True, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'nthread': -1, 'seed': 0}
# MEAN SCORE : make_scorer(<lambda>, greater_is_better=False) = -28401.733327750837
# VARIANCE : 4619.560447195813 (fold 1 = -28399.065734552853, fold 2 = -30243.232536849537, fold 3 = -26790.32629061096, fold 4 = -35383.37422071656, fold 5 = -21192.667856024276)
# CPU time: 0.6538031101226807 seconds
# 100%|██████████| 50/50 [00:38<00:00,  1.30it/s, best loss: 27900.1496177202]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ BEST HYPER-PARAMETERS ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# {'est__colsample_bytree': 0.8001505873930118, 'est__learning_rate': 0.07, 'est__max_depth': 9, 'est__n_estimators': 150, 'est__n_jobs': 4, 'est__strategy': 'LightGBM', 'est__subsample': 0.8001335821059329}

# %%
prd = Predictor()
prd.fit_predict(params, df)
# Out:
# fitting the pipeline ...
# CPU time: 0.14815711975097656 seconds
#
# > Feature importances dumped into directory : save
#
# predicting...
# CPU time: 0.0493316650390625 seconds
#
# > Overview on predictions :
#
#    SalePrice_predicted
# 0        126515.771485
# 1        154357.757515
# 2        179185.033749
# 3        183548.464490
# 4        182008.667972
# 5        174669.024861
# 6        172871.038341
# 7        169968.292019
# 8        176905.029256
# 9        120890.240177
#
# dumping predictions into directory : save ...

# %%
submit = pd.read_csv("sample_submission.csv",sep=',')
preds = pd.read_csv("save/"+target_name+"_predictions.csv")

submit[target_name] =  preds[target_name+"_predicted"].values

submit.to_csv("mlbox.csv", index=False)
